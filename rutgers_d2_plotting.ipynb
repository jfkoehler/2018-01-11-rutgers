# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a = [1]
range(5)
# Out:
# range(0, 5)

# %%
for num in range(5):
    next = a[num] + 1
    a.append(next)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
plt.figure(figsize = (8, 10))
plt.plot(a, '--o', label = "Line")
plt.title("My First Plot")
plt.xlabel("Here's my $x$")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.title?

# %%
ocean = pd.read_csv('data/gapminder_gdp_oceania.csv', index_col='country')

# %%
ocean.head()
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
plt.figure()
ocean.loc['Australia'].plot()
# Out:
# <img src="data:image/png;base64,..." width="872">

# %%
plt.xticks(rotation = 45)
# Out:
# (array([  0.,   2.,   4.,   6.,   8.,  10.,  12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
ocean.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
ocean.T.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.style.use('ggplot')
ocean.T.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ocean.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
plt.figure()
plt.plot(ocean.T["Australia"])
plt.plot(ocean.T["New Zealand"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
a = [1, 2, 3, 4]
b = [3, 5, 2, 3]
plt.bar(a, b)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 4 artists>

# %%
ocean.head()
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
plt.figure()
plt.bar(ocean.columns, ocean.loc['Australia'])
plt.bar(ocean.columns, ocean.loc['New Zealand'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 12 artists>

# %%
x = np.linspace(0, 10, 1000)
def f(x):
    return x**2

# %%
f(3)
# Out:
# 9

# %%
plt.figure()
plt.plot(x, f(x))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure()
sns.boxplot(x=tips["total_bill"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.boxplot(x = "day", y = "total_bill", hue = "smoker", data = tips)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.violinplot(x = "day", y = "total_bill", hue = "smoker", data = tips, split = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
gapminder = pd.read_csv('data/gapminder_all.csv')

# %%
gapminder.head()
# Out:
#   continent       country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa       Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa        Angola     3520.610273     3827.940465     4269.276742
# 2    Africa         Benin     1062.752200      959.601080      949.499064
# 3    Africa      Botswana      851.241141      918.232535      983.653976
# 4    Africa  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987    ...       pop_1962    pop_1967    pop_1972    pop_1977  \
# ...

# %%
gapminder.columns
# Out:
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957',
#        'lifeExp_1962', 'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977',
#        'lifeExp_1982', 'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997',
#        'lifeExp_2002', 'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962',
#        'pop_1967', 'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992',
#        'pop_1997', 'pop_2002', 'pop_2007'],
#       dtype='object')

# %%
plt.figure()
plt.scatter(gapminder["gdpPercap_2007"], gapminder["lifeExp_2007"], c = 'green', s = gapminder["pop_2007"]/10**6)
plt.xscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.polyfit(gapminder["gdpPercap_2007"], gapminder["lifeExp_2007"], 1)
# Out:
# array([  6.37134135e-04,   5.95656501e+01])

# %%
np.polyfit?

# %%
np.polyfit(gapminder["gdpPercap_2007"], gapminder["lifeExp_2007"], 1, full = True)
# Out:
# (array([  6.37134135e-04,   5.95656501e+01]),
#  array([ 11086.02615735]),
#  2,
#  array([ 1.29369006,  0.57128453]),
#  3.1530333899354446e-14)

# %%
def f(x):
    return x**2

# %%
a = np.linspace(0, 4, 5)

# %%
plt.figure()
plt.plot(a,f(a), 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.polyfit(a, f(a), 2)
# Out:
# array([  1.00000000e+00,  -3.98886964e-15,   4.38371093e-15])

# %%
plt.figure()
plt.plot(a[:2], f(a[:2]), 'o', color = 'blue')
plt.plot(a[2:], f(a[2:]), 'o', color = 'red')
# Out:
# <img src="data:image/png;base64,..." width="640">
